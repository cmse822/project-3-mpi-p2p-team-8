# %% [markdown]
# X: Bytes per message (10^0 ~ 10^?)
# Y: Average running time (10^-? ~10^-?)
# Separate lines for #of processors

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = r'comm_data_64_blocking.csv'
data = pd.read_csv(file_path)
print(data)
# Out:
#      Rank     Node  MessageSize  AverageTimePerExchange
# 0       0  nvf-004            2                0.000313
# 1       0  nvf-004            4                0.000004
# 2       0  nvf-004            8                0.000003
# 3       0  nvf-004           16                0.000004
# 4       0  nvf-004           32                0.000005
# ..    ...      ...          ...                     ...
# 763    63  nvf-005          256                0.000006
# 764    63  nvf-005          512                0.000006
# 765    63  nvf-005         1024                0.000010
# 766    63  nvf-005         2048                0.000020
# 767    63  nvf-005         4096                0.000033
#
# [768 rows x 4 columns]

# %%
data_r = data.groupby('Rank')

plt.figure(figsize=(10, 6))

for name, group in data_r:
    plt.plot(group['MessageSize'], group['AverageTimePerExchange'], marker='o', label=f'Rank {name}')

plt.title('Average Time Per Exchange vs. Message Size')
plt.xlabel('Message Size')
plt.ylabel('Average Time Per Exchange')
plt.xscale('log')
plt.yscale('log')
plt.legend(title='Rank')
plt.show()
